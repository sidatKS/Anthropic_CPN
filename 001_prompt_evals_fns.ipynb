# %% [markdown]
# <a href="https://colab.research.google.com/github/sidatKS/Anthropic_CPN/blob/main/001_prompt_evals_fns.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install anthropic
# Out:
# Collecting anthropic
#   Downloading anthropic-0.103.1-py3-none-any.whl.metadata (3.2 kB)
# Requirement already satisfied: anyio<5,>=3.5.0 in /usr/local/lib/python3.12/dist-packages (from anthropic) (4.13.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/local/lib/python3.12/dist-packages (from anthropic) (1.9.0)
# Requirement already satisfied: docstring-parser<1,>=0.15 in /usr/local/lib/python3.12/dist-packages (from anthropic) (0.18.0)
# Requirement already satisfied: httpx<1,>=0.25.0 in /usr/local/lib/python3.12/dist-packages (from anthropic) (0.28.1)
# Requirement already satisfied: jiter<1,>=0.4.0 in /usr/local/lib/python3.12/dist-packages (from anthropic) (0.14.0)
# Requirement already satisfied: pydantic<3,>=1.9.0 in /usr/local/lib/python3.12/dist-packages (from anthropic) (2.12.3)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.12/dist-packages (from anthropic) (1.3.1)
# Requirement already satisfied: typing-extensions<5,>=4.14 in /usr/local/lib/python3.12/dist-packages (from anthropic) (4.15.0)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.12/dist-packages (from anyio<5,>=3.5.0->anthropic) (3.13)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.25.0->anthropic) (2026.4.22)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.25.0->anthropic) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx<1,>=0.25.0->anthropic) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic<3,>=1.9.0->anthropic) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.4 in /usr/local/lib/python3.12/dist-packages (from pydantic<3,>=1.9.0->anthropic) (2.41.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/lib/python3.12/dist-packages (from pydantic<3,>=1.9.0->anthropic) (0.4.2)
# Downloading anthropic-0.103.1-py3-none-any.whl (832 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 832.6/832.6 kB 19.8 MB/s eta 0:00:00
# Installing collected packages: anthropic
# Successfully installed anthropic-0.103.1

# %%
from google.colab import userdata
import os
os.environ["ANTHROPIC_API_KEY"] = userdata.get('ANTHROPIC_API_KEY')
from anthropic import Anthropic
client = Anthropic()  # auto-picks up the env var
model = "claude-haiku-4-5"

# %%
# Helper functions
def add_user_message(messages, text):
    user_message = {"role": "user", "content": text}
    messages.append(user_message)


def add_assistant_message(messages, text):
    assistant_message = {"role": "assistant", "content": text}
    messages.append(assistant_message)


def chat(messages, system=None, temperature=1.0, stop_sequences=[]):
    params = {
        "model": model,
        "max_tokens": 1000,
        "messages": messages,
        "temperature": temperature,
        "stop_sequences": stop_sequences,
    }

    if system:
        params["system"] = system

    message = client.messages.create(**params)
    return message.content[0].text

# %%
# Function to generate a new dataset
import json


def generate_dataset():
    prompt = """
Generate a evaluation dataset for a prompt evaluation. The dataset will be used to evaluate prompts
that generate Python, JSON, or Regex specifically for AWS-related tasks. Generate an array of JSON objects,
each representing task that requires Python, JSON, or a Regex to complete.

Example output:
```json
[
    {
        "task": "Description of task",
        "format": "json" or "python" or "regex"
    },
    ...additional
]
```

* Focus on tasks that can be solved by writing a single Python function, a single JSON object, or a regular expression.
* Focus on tasks that do not require writing much code

Please generate 3 objects.
"""

    messages = []
    add_user_message(messages, prompt)
    add_assistant_message(messages, "```json")
    text = chat(messages, stop_sequences=["```"])
    return json.loads(text)

# %%
# Generate the dataset and write it to 'dataset.json'
dataset = generate_dataset()
with open("dataset.json", "w") as f:
    json.dump(dataset, f, indent=2)

# %%
# Function to grade a test case + output using a model
def grade_by_model(test_case, output):
    eval_prompt = f"""
You are an expert AWS code reviewer. Your task is to evaluate the following AI-generated solution.

Original Task:
<task>
{test_case["task"]}
</task>

Solution to Evaluate:
<solution>
{output}
</solution>

Output Format
Provide your evaluation as a structured JSON object with the following fields, in this specific order:
- "strengths": An array of 1-3 key strengths
- "weaknesses": An array of 1-3 key areas for improvement
- "reasoning": A concise explanation of your overall assessment
- "score": A number between 1-10

Respond with JSON. Keep your response concise and direct.
Example response shape:
{{
    "strengths": string[],
    "weaknesses": string[],
    "reasoning": string,
    "score": number
}}
    """

    messages = []
    add_user_message(messages, eval_prompt)
    add_assistant_message(messages, "```json")
    eval_text = chat(messages, stop_sequences=["```"])
    return json.loads(eval_text)

# %%
# Passes a test case into Claude
def run_prompt(test_case):
    prompt = f"""
Please solve the following task:

{test_case["task"]}

* Respond only with Python, JSON, or a plain Regex
* Do not add any comments or commentary or explanation
"""

    messages = []
    add_user_message(messages, prompt)
    add_assistant_message(messages, "```code")
    output = chat(messages, stop_sequences=["```"])
    return output

# %%
# Functions to validate the output structure
import re
import ast


def validate_json(text):
    try:
        json.loads(text.strip())
        return 10
    except json.JSONDecodeError:
        return 0


def validate_python(text):
    try:
        ast.parse(text.strip())
        return 10
    except SyntaxError:
        return 0


def validate_regex(text):
    try:
        re.compile(text.strip())
        return 10
    except re.error:
        return 0


def grade_syntax(response, test_case):
    format = test_case["format"]
    if format == "json":
        return validate_json(response)
    elif format == "python":
        return validate_python(response)
    else:
        return validate_regex(response)

# %%
# Function to execute a single test case and grade the output
def run_test_case(test_case):
    """Calls run_prompt, then grades the result"""
    output = run_prompt(test_case)

    model_grade = grade_by_model(test_case, output)
    model_score = model_grade["score"]
    reasoning = model_grade["reasoning"]

    syntax_score = grade_syntax(output, test_case)

    score = (model_score + syntax_score) / 2

    return {
        "output": output,
        "test_case": test_case,
        "score": score,
        "reasoning": reasoning,
    }

# %%
from statistics import mean


def run_eval(dataset):
    """Loads the dataset and calls run_test_case with each case"""
    results = []

    for test_case in dataset:
        result = run_test_case(test_case)
        results.append(result)

    average_score = mean([result["score"] for result in results])
    print(f"Average score: {average_score}")

    return results

# %%
with open("dataset.json", "r") as f:
    dataset = json.load(f)

results = run_eval(dataset)
# Out:
# Average score: 8.333333333333334

# %%
print(json.dumps(results, indent=2))
# Out:
# [
#   {
#     "output": "\nimport re\n\ndef extract_bucket_name(s3_uri):\n    match = re.match(r's3://([^/]+)', s3_uri)\n    return match.group(1) if match else None\n",
#     "test_case": {
#       "task": "Parse an AWS S3 bucket name from an S3 URI in the format 's3://bucket-name/key/path' and extract just the bucket name",
#       "format": "regex"
#     },
#     "score": 8.5,
#     "reasoning": "The solution correctly solves the basic parsing task with a clean approach. However, it lacks robustness for production use: it should validate input types and ideally enforce AWS S3 bucket naming constraints. The regex itself is sound for standard cases, but doesn't account for alternative S3 URI schemes. For a simple parsing function, this is adequate; for a production utility, additional validation would be expected."
#   },
#   {
#     "output": "\n{\n  \"AWSTemplateFormatVersion\": \"2010-09-09\",\n  \"Resources\": {\n    \"EC2InstanceRole\": {\n      \"Type\": \"AWS::IAM::Role\",\n      \"Properties\": {\n        \"AssumeRolePolicyDocument\": {\n          \"Version\": \"2012-10-17\",\n          \"Statement\": [\n            {\n              \"Effect\": \"Allow\",\n              \"Principal\": {\n                \"Service\": \"ec2.amazonaws.com\"\n              },\n              \"Action\": \"sts:AssumeRole\"\n            }\n          ]\n        },\n        \"Path\": \"/\",\n        \"RoleName\": \"EC2InstanceRole\"\n      }\n    }\n  }\n}\n",
#     "test_case": {
#       "task": "Create a JSON CloudFormation template snippet that defines an AWS IAM role with a trust policy allowing EC2 instances to assume it",
#       "format": "json"
#     },
#     "score": 8.5,
#     "reasoning": "The solution correctly implements the core requirement of defining an IAM role with a valid EC2 trust policy. The JSON syntax and CloudFormation structure are sound. However, it lacks production-ready security practices (condition statements) and practical completeness (no permissions attached). The hardcoded RoleName is also a minor anti-pattern. These issues prevent this from being a fully enterprise-ready template, though it successfully addresses the basic task requirements."
#   },
#   {
#     "output": "\nimport base64\nimport json\nfrom typing import Any, Dict, Union\n\ndef extract_body_from_api_gateway_v2(event: Dict[str, Any]) -> Union[str, Dict[str, Any], None]:\n    \"\"\"\n    Extracts the HTTP request body from an API Gateway v2 payload.\n    Handles both string and base64-encoded content.\n    \n    Args:\n        event: AWS Lambda event object from API Gateway v2\n        \n    Returns:\n        Parsed body content as string, dict, or None if no body present\n    \"\"\"\n    body = event.get('body')\n    \n    if body is None:\n        return None\n    \n    is_base64_encoded = event.get('isBase64Encoded', False)\n    \n    if is_base64_encoded:\n        try:\n            body = base64.b64decode(body).decode('utf-8')\n        except Exception:\n            return body\n    \n    content_type = event.get('headers', {}).get('content-type', '').lower()\n    \n    if 'application/json' in content_type:\n        try:\n            return json.loads(body)\n        except json.JSONDecodeError:\n            return body\n    \n    return body\n\n\ndef extract_body_from_api_gateway_v1(event: Dict[str, Any]) -> Union[str, Dict[str, Any], None]:\n    \"\"\"\n    Extracts the HTTP request body from an API Gateway v1 payload.\n    Handles both string and base64-encoded content.\n    \n    Args:\n        event: AWS Lambda event object from API Gateway v1\n        \n    Returns:\n        Parsed body content as string, dict, or None if no body present\n    \"\"\"\n    body = event.get('body')\n    \n    if body is None:\n        return None\n    \n    is_base64_encoded = event.get('isBase64Encoded', False)\n    \n    if is_base64_encoded:\n        try:\n            body = base64.b64decode(body).decode('utf-8')\n        except Exception:\n            return body\n    \n    headers = event.get('headers', {})\n    content_type = None\n    \n    for key, value in headers.items():\n        if key.lower() == 'content-type':\n            content_type = value.lower()\n            break\n    \n    if content_type and 'application/json' in content_type:\n        try:\n            return json.loads(body)\n        except json.JSONDecodeError:\n            return body\n    \n    return body\n",
#     "test_case": {
#       "task": "Write a Python function that takes an AWS Lambda event object and extracts the HTTP request body from an API Gateway v2 payload, handling both string and base64-encoded content",
#       "format": "python"
#     },
#     "score": 8.0,
#     "reasoning": "The solution correctly implements the core requirement of extracting and parsing bodies from API Gateway v2 events with proper handling of base64 encoding and JSON content. However, it deviates from the original task scope by including v1 functionality, introduces maintainability issues through code duplication, and uses problematic exception handling patterns. The broad exception catching could hide encoding errors or other issues. While the logic is functionally sound for typical use cases, the implementation quality and adherence to requirements could be improved."
#   }
# ]
